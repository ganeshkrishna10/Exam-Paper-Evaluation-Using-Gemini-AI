# %%
import os
import google.generativeai as genai
from PIL import Image
import io

# Configure the API key
api_key = "AIzaSyDU-VfmFkD_zKuikWM85mrgr8vecFa3b7s"
os.environ["GEMINI_API_KEY"] = api_key
genai.configure(api_key=api_key)

def upload_to_gemini(image_path):
    """Uploads the given image file to Gemini."""
    return genai.upload_file(image_path, mime_type="image/jpeg")

def process_image(image_path):
    """Processes the uploaded image and returns its binary data."""
    try:
        with open(image_path, "rb") as image_file:
            image_data = image_file.read()
            return image_data
    except Exception as e:
        print(f"Error processing image: {e}")
        return None

def chat_with_model(input_text, image_data):
    """Starts a chat session with the Gemini model."""
    generation_config = {
        "temperature": 1,
        "top_p": 0.95,
        "top_k": 64,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }
    safety_settings = [
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
    ]

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        safety_settings=safety_settings,
        generation_config=generation_config,
    )

    try:
        chat_session = model.start_chat(
            history=[
                {
                    "role": "user",
                    "parts": [
                        {"text": input_text},
                        {"inline_data": {"mime_type": "image/jpeg", "data": image_data}}
                    ],
                }
            ]
        )
        response = chat_session.send_message({"text": input_text})
        return response.text
    except Exception as e:
        return f"An error occurred: {str(e)}"

def interact_with_model():
    """Interacts with the Gemini model."""
    # Upload image
    image_path = input("Enter the path to the image file: ")
    if not os.path.exists(image_path):
        print("File not found.")
        return

    image_data = process_image(image_path)
    if not image_data:
        print("Failed to process image.")
        return

    # Ask question related to the image
    question = input("Ask a question related to the image: ")
    if not question.strip():
        print("Question cannot be empty.")
        return

    # Interact with model
    response = chat_with_model(question, image_data)
    print("Response from model:")
    print(response)

# Sample usage
interact_with_model()
# Out:
# Enter the path to the image file: /content/ques3.jpg
# Ask a question related to the image: how many questions
# Response from model:
# There are 2 questions.

# %%
import os
import google.generativeai as genai
from PIL import Image
import io

# Configure the API key
api_key = "AIzaSyDU-VfmFkD_zKuikWM85mrgr8vecFa3b7s"
os.environ["GEMINI_API_KEY"] = api_key
genai.configure(api_key=api_key)

def upload_to_gemini(image_path):
    """Uploads the given image file to Gemini."""
    return genai.upload_file(image_path, mime_type="image/jpeg")

def process_image(image_path):
    """Processes the uploaded image and returns its binary data."""
    try:
        with open(image_path, "rb") as image_file:
            image_data = image_file.read()
            return image_data
    except Exception as e:
        print(f"Error processing image: {e}")
        return None

def chat_with_model(input_text, image_data):
    """Starts a chat session with the Gemini model."""
    generation_config = {
        "temperature": 1,
        "top_p": 0.95,
        "top_k": 64,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }
    safety_settings = [
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
    ]

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        safety_settings=safety_settings,
        generation_config=generation_config,
    )

    try:
        chat_session = model.start_chat(
            history=[
                {
                    "role": "user",
                    "parts": [
                        {"text": input_text},
                        {"inline_data": {"mime_type": "image/jpeg", "data": image_data}}
                    ],
                }
            ]
        )
        response = chat_session.send_message({"text": input_text})
        return response.text
    except Exception as e:
        return f"An error occurred: {str(e)}"

def interact_with_model():
    """Interacts with the Gemini model."""
    # Upload image
    image_path = input("Enter the path to the image file: ")
    if not os.path.exists(image_path):
        print("File not found.")
        return

    image_data = process_image(image_path)
    if not image_data:
        print("Failed to process image.")
        return

    # Ask question related to the image
    question = input("Ask a question related to the image: ")
    if not question.strip():
        print("Question cannot be empty.")
        return

    # Interact with model
    response = chat_with_model(question, image_data)
    print("Response from model:")
    print(response)

# Sample usage
interact_with_model()
# Out:
# Enter the path to the image file: /content/ques3.jpg
# Ask a question related to the image: how many incorrect questions
# Response from model:
# There are no incorrect questions in the provided text. The text is a set of math problems with solutions.

# %%
# !pip install pytesseract

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 2s (2,870 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import os
import google.generativeai as genai
from PIL import Image
import pytesseract

# Configure the API key
api_key = "AIzaSyDU-VfmFkD_zKuikWM85mrgr8vecFa3b7s"
os.environ["GEMINI_API_KEY"] = api_key
genai.configure(api_key=api_key)

def upload_to_gemini(image_path):
    """Uploads the given image file to Gemini."""
    return genai.upload_file(image_path, mime_type="image/jpeg")

def process_image(image_path):
    """Processes the uploaded image and returns its binary data and extracted text."""
    try:
        with open(image_path, "rb") as image_file:
            image_data = image_file.read()
            text = pytesseract.image_to_string(Image.open(image_path))
            return image_data, text
    except Exception as e:
        print(f"Error processing image: {e}")
        return None, None

def chat_with_model(input_text, image_data):
    """Starts a chat session with the Gemini model."""
    generation_config = {
        "temperature": 1,
        "top_p": 0.95,
        "top_k": 64,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }
    safety_settings = [
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
    ]

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        safety_settings=safety_settings,
        generation_config=generation_config,
    )

    try:
        chat_session = model.start_chat(
            history=[
                {
                    "role": "user",
                    "parts": [
                        {"text": input_text},
                        {"inline_data": {"mime_type": "image/jpeg", "data": image_data}}
                    ],
                }
            ]
        )
        response = chat_session.send_message({"text": input_text})
        return response.text
    except Exception as e:
        return f"An error occurred: {str(e)}"

def detect_marks(text):
    """Detects marks from the extracted text."""
    # Add your logic to detect marks here
    return "Marks detected: 8 out of 10"  # Placeholder response

def interact_with_model():
    """Interacts with the Gemini model."""
    # Upload image
    image_path = input("Enter the path to the image file: ")
    if not os.path.exists(image_path):
        print("File not found.")
        return

    image_data, extracted_text = process_image(image_path)
    if not image_data or not extracted_text:
        print("Failed to process image.")
        return

    # Ask question related to the image
    question = input("Ask a question related to the image: ")
    if not question.strip():
        print("Question cannot be empty.")
        return

    # Interact with model
    response = chat_with_model(question, image_data)
    print("Response from model:")
    print(response)

    # Detect marks from the extracted text
    marks_result = detect_marks(extracted_text)
    print(marks_result)

# Sample usage
interact_with_model()
# Out:
# Enter the path to the image file: /content/ques3.jpg
# Ask a question related to the image: Please analyze this exam paper and identify any mistakes in the answers provided. Also, suggest the correct answers.
# Response from model:
# **Question 3:**
#
# The answer provided is correct. The HCF of 616 and 32 is 8, which is found correctly using Euclid's algorithm. Therefore, they can march in 8 columns each.
#
# **Question 4:**
#
# The answer provided is incorrect. The mistake lies in the assumption that the remainder 'r' can be 3. The remainder 'r' should be less than the divisor, which is 3. Therefore, 'r' can only be 0, 1, or 2.
#
# Here's the corrected solution:
#
# Let 'a' be any positive integer and 'b' = 3.
# Then 'a = 3q + r' for some integer 'q ≥ 0'.
#
# And 'r = 0, 1, 2' because '0 ≤ r < 3'.
#
# Therefore, 'a = 3q or 3q + 1 or 3q + 2'.
#
# Now, let's square each of these:
#
# a² = (3q)² or (3q + 1)² or (3q + 2)²
#     = (3q)² or 9q² + 6q + 1 or 9q² + 12q + 4
# ...

# %%
# !pip install pyttsx3

# %%
# !pip install gtts

# %%
import os
import google.generativeai as genai
from PIL import Image
import pytesseract
from gtts import gTTS
import IPython.display as ipd

# Configure the API key
api_key = "AIzaSyDU-VfmFkD_zKuikWM85mrgr8vecFa3b7s"
os.environ["GEMINI_API_KEY"] = api_key
genai.configure(api_key=api_key)

def upload_to_gemini(image_path):
    """Uploads the given image file to Gemini."""
    return genai.upload_file(image_path, mime_type="image/jpeg")

def process_image(image_path):
    """Processes the uploaded image and returns its binary data and extracted text."""
    try:
        with open(image_path, "rb") as image_file:
            image_data = image_file.read()
            text = pytesseract.image_to_string(Image.open(image_path))
            return image_data, text
    except Exception as e:
        print(f"Error processing image: {e}")
        return None, None

def chat_with_model(input_text, image_data):
    """Starts a chat session with the Gemini model."""
    generation_config = {
        "temperature": 1,
        "top_p": 0.95,
        "top_k": 64,
        "max_output_tokens": 8192,
        "response_mime_type": "text/plain",
    }
    safety_settings = [
        {
            "category": "HARM_CATEGORY_HARASSMENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_HATE_SPEECH",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
        {
            "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
            "threshold": "BLOCK_MEDIUM_AND_ABOVE",
        },
    ]

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        safety_settings=safety_settings,
        generation_config=generation_config,
    )

    try:
        chat_session = model.start_chat(
            history=[
                {
                    "role": "user",
                    "parts": [
                        {"text": input_text},
                        {"inline_data": {"mime_type": "image/jpeg", "data": image_data}}
                    ],
                }
            ]
        )
        response = chat_session.send_message({"text": input_text})
        return response.text
    except Exception as e:
        return f"An error occurred: {str(e)}"

def detect_marks(text):
    """Detects marks from the extracted text."""
    # Add your logic to detect marks here
    return "Marks detected: 8 out of 10"  # Placeholder response

def speak(text):
    """Converts text to speech using gTTS."""
    tts = gTTS(text)
    tts.save("output.mp3")
    ipd.display(ipd.Audio("output.mp3"))

def interact_with_model():
    """Interacts with the Gemini model."""
    # Upload image
    image_path = input("Enter the path to the image file: ")
    if not os.path.exists(image_path):
        print("File not found.")
        return

    image_data, extracted_text = process_image(image_path)
    if not image_data or not extracted_text:
        print("Failed to process image.")
        return

    # Ask question related to the image
    question = input("Ask a question related to the image: ")
    if not question.strip():
        print("Question cannot be empty.")
        return

    # Interact with model
    response = chat_with_model(question, image_data)
    print("Response from model:")
    print(response)
    speak(response)  # Voice output for the response

    # Detect marks from the extracted text
    marks_result = detect_marks(extracted_text)
    print(marks_result)
    speak(marks_result)  # Voice output for the marks result

# Sample usage
interact_with_model()
# Out:
# Enter the path to the image file: /content/ques3.jpg
# Ask a question related to the image: Please analyze this exam paper and identify any mistakes in the answers provided. Also, suggest the correct answers.
# Response from model:
# **Question 3:**
#
# The answer provided is correct. The HCF (616, 32) is indeed 8, and therefore, the army contingent can march in 8 columns each.
#
# **Question 4:**
#
# The answer provided is partially correct but lacks complete justification.
#
# The mistake lies in the assumption that a = 3q + r, where r = 0, 1, or 2. While this is true, it doesn't cover all possible scenarios for a positive integer 'a'.
#
# **Here's a more complete and corrected explanation:**
#
# * **Using Euclid's division lemma:** Every positive integer 'a' can be expressed as a = bq + r, where 'b' is a positive integer (in this case, b = 3), 'q' is the quotient, and 'r' is the remainder (0 ≤ r < b).
#
# ...
